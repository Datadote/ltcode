# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
       # Put nums in a dict. Then iterate through and see if
        # dict has corresponding number
        
        d = {}
        for i, num in enumerate(nums):
            d[num] = d.get(num, []) + [i]
        keys = d.keys()
        
        try: # Case where 6, and [3,3]
            if target%2==0 and len(d[target/2])==2:
                return d[target/2]
        except:
            pass
        
        for k in keys:
            # k1 + k2 = target -> find k2 = target-k1
            if target-k in keys and k != target/2:
                return d[k] + d[target-k]
    

#     # Make a sorted list. For all positive values, check if the 
#        # Special case where even number, and double of integer
# #         nums_sorted = sorted(nums)

#         # Sol 2: Faster 80 ms, 15.4 MB
#         # nums can be a sum of a larger and a smaller number
#         # sort first? bin into dictionary?
#         # 1) if target is even, and /2 has 2 hits, then return those indices
#         d = {}
#         half_num = target/2
        
#         # Covers special case with even number, and same number 2x
#         if target%2 == 0:
#             indices = []
#             for i, num in enumerate(nums):
#                 if num == half_num:
#                     indices.append(i)
#             if len(indices) == 2:
#                 return indices
        
#         for i, num in enumerate(nums):
#             d[num] = i

#         for k in d:
#             if k != half_num:
#                 if target-k in d:
#                     return [d[k], d[target-k]]

        
#         # Sol 1: Slow, 4500 ms, but passes, 15 MB
#         # for i1, num1 in enumerate(nums):
#         #     for i2, num2 in enumerate(nums[i1+1:], 1):
#         #        # print(num1, num2)
#         #         if num1+num2 == target:
#         #             return [i1,i1+i2]
