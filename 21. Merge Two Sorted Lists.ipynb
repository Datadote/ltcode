# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        # Make dummy, tail. Point to first value
        # Move tail along based on list1 and list2 values
        # Lists are sorted in non-decreasing order
        # If one list is empty, append rest to tail
        # Return dummy.next for the head of the merged list
        
        dummy = tail = ListNode()

        while list1 and list2:
            if list1.val <= list2.val:
                tail.next, list1 = list1, list1.next
            else:
                tail.next, list2 = list2, list2.next
            tail = tail.next
        
        rest = list1 or list2
        tail.next = rest
        
        return dummy.next
    
#     # V2
#         head = ListNode()
#         tail = head # new tail object created that head.next references to
#         # head.next = tail
        
#         # print('equiv?', head==tail)
#         # print('next? start', head.next==tail.next)
#         # print('next? start', head.next==tail)
        
#         # While both lists exist, compare first element,
#         # Set next node to lower element, and increment that listNode's next value
        
#         while list1 and list2:
#             if list1.val < list2.val:
#                 # print(list1.val)
#                 tail.next = list1
#                 list1 = list1.next
#             else:
#                 # print(list2.val)
#                 tail.next = list2
#                 list2 = list2.next
#             tail = tail.next
                
#         if list1 is None:
#             tail.next = list2
#         elif list2 is None:
#             tail.next = list1
            
#         # print('next? start', head.next==tail.next)
            
#         return head.next
        
# V1 works? or not

# class Solution:
#     def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
#         headNode = self.nextNode(list1, list2)
#         return headNode
    
#     def nextNode(self, list1, list2):
#         if (list1 is None) and (list2 is None):
#             return None
#         elif (list1 is None):
#             return list2
#         else:
#             return list1
        
#         if list1.val > list2.val:
#             return list2
#         else:
#             return list1
    
#     def AtEnd(self, llist, newData):
#         newNode = ListNode(newData)
#         if llist is None:
#             llist = newNode
#             return
#         laste = llist
#         while laste.next:
#             laste = laste.next
#         laste.next = newNode
